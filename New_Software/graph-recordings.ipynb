# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
os.chdir("/Users/joshuasu/Documents/EOG-Software")

# %%
sim = pd.read_csv("./recordings/csv_outputs/up_down_blink_3_4-8.csv")

data = sim['Data 1']
time = list(range(sim.shape[0]))

plt.plot(time, data)

# %%
sim = pd.read_csv("./recordings/csv_outputs/UDB1.csv")

data = sim['data1']
time = list(range(sim.shape[0]))

plt.plot(time, data)
